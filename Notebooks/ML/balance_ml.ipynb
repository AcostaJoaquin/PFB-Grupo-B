# %%
import pandas as pd 
import numpy as np

# %%
balance_df = pd.read_csv("../Obtencion datos/balance_electrico.csv")

balance_df
# Out:
#      Unnamed: 0                nombre    tipo de energía      Valores  \
# 0             0  Renewable generation          Renewable  283293.8550
# 1             1  Renewable generation          Renewable  315791.7010
# 2             2  Renewable generation          Renewable  358667.5460
# 3             3  Renewable generation          Renewable  312348.7135
# 4             4  Renewable generation          Renewable  306444.6200
# ..          ...                   ...                ...          ...
# 178         178     Demand at busbars  Demand at busbars  695597.3890
# 179         179     Demand at busbars  Demand at busbars  689988.5230
# 180         180     Demand at busbars  Demand at busbars  602468.7460
# 181         181     Demand at busbars  Demand at busbars  547492.9340
# 182         182     Demand at busbars  Demand at busbars  638740.3510
#
#      Porcentaje Fecha actualización
# 0             1          28/07/2022
# 1             1          29/07/2022
# ...
