# %%
import requests

from datetime import datetime, timedelta

# %%
lang    =  "es"
category = "balance"
widget   = "balance-electrico"
query   = "start_date=2019-01-01T00:00&end_date=2019-01-31T23:59&time_trunc=day"

#query_30 =

# %%
headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Host' : 'apidatos.ree.es'
}

# %%
## SAMPLE URL

#https://apidatos.ree.es/es/datos/balance/balance-electrico?start_date=2019-01-01T00:00&end_date=2019-01-31T23:59&time_trunc=day

# %%
endpoint = f"https://apidatos.ree.es/{lang}/datos/{category}/{widget}?{query}"
response = requests.get(url = endpoint, headers = headers)
data = response.json()
data
# Out:
# {'data': {'type': 'Balance de energía eléctrica',
#   'id': 'bal1',
#   'attributes': {'title': 'Balance de energía eléctrica',
#    'last-update': '2020-01-10T08:15:41.000+01:00',
#    'description': 'Balance eléctrico: asignación de unidades de producción según combustible principal. La producción neta de las instalaciones no renovables e hidráulicas UGH tiene descontados los consumos propios de las instalaciones. En dichos tipos de producción una generación negativa indica que la electricidad horaria consumida para los usos de las plantas excede la producción horaria de las instalaciones.'},
#   'meta': {'cache-control': {'cache': 'HIT',
#     'expireAt': '2024-10-24T08:47:19'}}},
#  'included': [{'type': 'Renovable',
#    'id': 'Renovable',
#    'attributes': {'title': 'Renovable',
#     'last-update': '2020-01-10T08:15:21.000+01:00',
#     'description': None,
#     'magnitude': None,
#     'content': [{'type': 'Hidráulica',
#       'id': '10288',
# ...

# %% [markdown]
# # OBTENCIÓN DE DATOS DE LOS ÚLTIMOS 7, 14 Y 30 DÍAS

# %%
lang    =  input('¿En español (es) o en inglés (en)?') 
category = input('¿Balance, demanda, generación o intercambio?') 
widget   = input()

#Creación de una query que se pueda actualizar a los resultados de los ultimos 7, 14 y 30:

restaDia = float(input())

now = datetime.now()
ultima_fecha = (now - timedelta(days = restaDia)).strftime('%Y-%m-%d')

hoy = now.strftime('%Y-%m-%d')

query = f"start_date={ultima_fecha}T00:00&end_date={hoy}T23:59&time_trunc=day"

# %%
headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Host' : 'apidatos.ree.es'
}

# %%
endpoint = f"https://apidatos.ree.es/{lang}/datos/{category}/{widget}?{query}"
response = requests.get(url = endpoint, headers = headers)
data = response.json()
data
# Out:
# {'data': {'type': 'Electrical energy balance',
#   'id': 'bal1',
#   'attributes': {'title': 'Electrical energy balance',
#    'last-update': '2024-09-24T11:03:01.000+02:00',
#    'description': "Electrical energy balance: Allocation of production units according to primary fuel. The self-consumption of manageable hydroelectric and non-renewable facilities is removed from their net production. In these types of generating facilities, a negative generation indicates that the hourly electricity consumption required by the power station for its operation exceeds the facility's hourly production."},
#   'meta': {'cache-control': {'cache': 'MISS'}}},
#  'included': [{'type': 'Renewable',
#    'id': 'Renewable',
#    'attributes': {'title': 'Renewable',
#     'last-update': '2024-09-24T11:02:58.000+02:00',
#     'description': None,
#     'magnitude': None,
#     'content': [{'type': 'Hydro',
#       'id': '10288',
#       'groupId': 'Renewable',
#       'attributes': {'title': 'Hydro',
# ...
